# %% [markdown]
# # Titanic
#
# In this challenge, we ask you to build a predictive model that answers the question: “what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).

# %% [markdown]
# ## Expected steps:
#
# 1. Check every categorical feature and convert it to one-hot encoding
# 2. Do EDA for continuous features. <br/>
#     (Using this sequence help ensure that all categorical variables have been converted to one-hot encoding to ensure that we are able to use them for Imputing values in Age variable)
#
#
# ## Outlier Detection:
# 1. IQR or Windsorization
# 2. Based of Skew. Should range between -1 (left-skewed) and 1 (right skewed)
# 3. Boxplot
# 4. Histogram
# 5. Scatterplot (for two variables)
#
# ## How to address Outliers:
# 1. Quartile based cealing and flooring
# 2. Log transformation -> log, sq. root or square

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import shapiro
import math

# Ignoring all warnings
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth',3000)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
gender = pd.read_csv('gender_submission.csv')

# %%
original = pd.read_csv('train.csv')

# %%
# Rearrrange the columns and remove passanger ID
train = train[['Survived', 'Pclass', 'Name', 'Sex',  'SibSp',
       'Parch', 'Ticket', 'Cabin', 'Embarked', 'Age', 'Fare']]

# %% [markdown]
# ## EDA

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Cabin       687
# Embarked      2
# Age         177
# Fare          0
# dtype: int64

# %%
train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# SibSp         int64
# Parch         int64
# Ticket       object
# Cabin        object
# Embarked     object
# Age         float64
# Fare        float64
# dtype: object

# %% [markdown]
# ## <b>Pclass </b>
# Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of passangers per Pclass', fontweight="bold")
bars = ax.bar(train.Pclass.unique(), train.Pclass.value_counts(), tick_label=train.Pclass.unique())
plt.xlabel('Pclasses')
plt.ylabel(' Number of passangers')
ax.bar_label(bars)

# plt.bar(train.Pclass.unique(), train.Pclass.value_counts())
# plt.xticks(train.Pclass.unique())
# Out:
# [Text(0, 0, '491'), Text(0, 0, '216'), Text(0, 0, '184')]

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of passangers per Pclass', fontweight="bold")
y = sns.countplot(x='Pclass', data=train)
plt.xlabel('Pclasses')
plt.ylabel(' Number of passangers')

y.bar_label(y.containers[0]);

# %%
#sns.barplot(x='Pclass', y='Survived', hue='Survived', data=train)

fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Survivors per Pclass', fontweight="bold")
y = sns.histplot(x='Pclass', hue='Survived', data=train, stat='count', multiple='dodge')
plt.xlabel('Pclass')
plt.ylabel('Survived / Died count')
plt.xticks(train.Pclass.unique())

labels1 = [str(v) if v else '' for v in y.containers[0].datavalues]
labels2 = [str(v) if v else '' for v in y.containers[1].datavalues]

y.bar_label(y.containers[0], labels=labels1)
y.bar_label(y.containers[1], labels=labels2);

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Survivors per Pclass', fontweight="bold")

y=sns.countplot(x='Pclass', hue='Survived', data=train)
plt.xlabel('Pclass')
plt.ylabel('Survived / Died count')

y.bar_label(y.containers[0])
y.bar_label(y.containers[1]);

# %% [markdown]
# ## <b> Name </b>

# %%
train['LastName'] = train.Name.str.split(',', expand=True)[0]
train['PaTitle'] = (train.Name.str.split(',', expand=True)[1].str.split('.', expand=True)[0]).str.strip()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Survivors per Passanger Title', fontweight="bold")

y=sns.countplot(x='PaTitle', hue='Survived', data=train)
plt.xlabel('Passanger Title')
plt.ylabel('Survived / Died count')

y.bar_label(y.containers[0])
y.bar_label(y.containers[1]);

# %%
# Regroup Passanger Titles as Other
train.loc[~((train['PaTitle'].str.contains('Mrs')) | 
            (train['PaTitle'].str.contains('Miss')) | 
            (train['PaTitle'].str.contains('Mr')) | 
            (train['PaTitle'].str.contains('Master'))), 'PaTitle'  ] = 'Others'

train.PaTitle.value_counts()
# Out:
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Others     27
# Name: PaTitle, dtype: int64

# %%
# Drop the name column as its of no use now
train.drop(['Name', 'LastName'], axis=1, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Survivors per Passanger Title', fontweight="bold")

y=sns.countplot(x='PaTitle', hue='Survived', data=train)
plt.xlabel('Passanger Title')
plt.ylabel('Survived / Died count')

y.bar_label(y.containers[0])
y.bar_label(y.containers[1]);

# %%
train = pd.get_dummies(train, columns=['PaTitle'], drop_first=True)

# %% [markdown]
# ## <b>Sex</b>

# %%
plt.figure(figsize = (15, 5))
plt.title('Total passengers of each gender', fontweight="bold")
y = sns.countplot(x='Sex', data=train)
plt.ylabel('Total Passengers')
y.bar_label(y.containers[0]);

# %%
plt.figure(figsize = (15, 5))
plt.title('Surviving Passenger for each gender', fontweight="bold")
y = sns.countplot(x='Sex', hue='Survived', data=train)
plt.ylabel('Total Passengers')
y.bar_label(y.containers[0])
y.bar_label(y.containers[1]);

# %%
# Convert Sex into One-hot encoding

train = pd.get_dummies(train, columns=['Sex'], drop_first=True).rename(columns={'Sex_male':'Sex'})

# %% [markdown]
# ## <b>SibSp</b>
#
# No. of siblings / spouses aboard the Titanic

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of SibSp', fontweight="bold")
y = sns.countplot(x='SibSp', data=train)
plt.xlabel('SibSp')
plt.ylabel(' Number of passangers')

y.bar_label(y.containers[0]);

# %%
# fig, ax = plt.subplots(figsize=(15, 5))
# plt.title('Number of passangers per Pclass', fontweight="bold")
# bars = ax.bar(train.SibSp.value_counts().index, train.SibSp.value_counts(), tick_label=train.SibSp.value_counts().index)
# plt.xlabel('Pclasses')
# plt.ylabel(' Number of passangers')

# ax.bar_label(bars)

# %%
train.SibSp.value_counts(normalize=True)
# Out:
# 0    0.682379
# 1    0.234568
# 2    0.031425
# 4    0.020202
# 3    0.017957
# 8    0.007856
# 5    0.005612
# Name: SibSp, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of SibSp', fontweight="bold")
y = sns.countplot(x='SibSp', hue='Survived', data=train)
plt.xlabel('SibSp')
plt.ylabel(' Number of passangers')

y.bar_label(y.containers[0]);
y.bar_label(y.containers[1]);

# %%
# Any SibSp >= 4, is set yo 4

train['SibSp'] = train['SibSp'].apply(lambda x: 4 if x>3 else x)

# %%
train.SibSp.value_counts().sort_index()
# Out:
# 0    608
# 1    209
# 2     28
# 3     16
# 4     30
# Name: SibSp, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of SibSp', fontweight="bold")
y = sns.countplot(x='SibSp', hue='Survived', data=train)
plt.xlabel('SibSp')
plt.ylabel(' Number of passangers')

y.bar_label(y.containers[0]);
y.bar_label(y.containers[1]);

# %% [markdown]
# ## <b>Parch</b>
# No. of parents / children aboard the Titanic

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Parch', fontweight="bold")
y = sns.countplot(x='Parch', data=train)
plt.xlabel('Parch')
plt.ylabel(' Number of passangers')

y.bar_label(y.containers[0]);

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Parch', fontweight="bold")
y = sns.countplot(x='Parch', hue='Survived', data=train)
plt.xlabel('Parch')
plt.ylabel(' Number of passangers')
plt.legend(loc='upper center', title='Survived')

y.bar_label(y.containers[0]);
y.bar_label(y.containers[1]);

# %%
train['Parch'] = train['Parch'].apply(lambda x: 3 if x>2 else x)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title('Number of Parch', fontweight="bold")
y = sns.countplot(x='Parch', hue='Survived', data=train)
plt.xlabel('Parch')
plt.ylabel(' Number of passangers')
plt.legend(loc='upper center', title='Survived')

y.bar_label(y.containers[0]);
y.bar_label(y.containers[1]);

# %% [markdown]
# ## <b>Ticket</b>

# %%
#train.Ticket.isnull().sum()
temp = train.copy()
temp = pd.concat([temp, temp.Ticket.str.split(' ', expand=True, n=1).rename(columns={0:'Ticket_P1', 1:'Ticket_P2'})], axis=1)

# %%
temp[temp.Ticket_P2.isnull()]['Survived'].value_counts(normalize=True)
# Out:
# 0    0.616541
# 1    0.383459
# Name: Survived, dtype: float64

# %%
temp[~temp.Ticket_P2.isnull()]['Survived'].value_counts(normalize=True)
# Out:
# 0    0.615044
# 1    0.384956
# Name: Survived, dtype: float64

# %%
# As we can see, there is no relation between tickets with alphanumeric numbers vs tickets without alphanumeric numbers. So we can ignore the newly created two columns.

# %%
# Understand what same ticket for several passanges means

train.sort_values('Ticket')
# Out:
#      Survived  Pclass  SibSp  Parch       Ticket Cabin Embarked   Age    Fare  \
# 504         1       1      0      0       110152   B79        S  16.0  86.500
# 257         1       1      0      0       110152   B77        S  30.0  86.500
# 759         1       1      0      0       110152   B77        S  33.0  86.500
# 262         0       1      1      1       110413   E67        S  52.0  79.650
# 558         1       1      1      1       110413   E67        S  39.0  79.650
# ..        ...     ...    ...    ...          ...   ...      ...   ...     ...
# 235         0       3      0      0   W./C. 6609   NaN        S   NaN   7.550
# 92          0       1      1      0  W.E.P. 5734   E31        S  46.0  61.175
# 219         0       2      0      0    W/C 14208   NaN        S  30.0  10.500
# 540         1       1      0      2    WE/P 5735   B22        S  36.0  71.000
# 745         0       1      1      1    WE/P 5735   B22        S  70.0  71.000
#
# ...

# %%
train = train.merge(train.groupby(by = 'Ticket').count().rename(columns={'Survived':'Ticket_Count'})['Ticket_Count'], on='Ticket', how='left')

# %%
train['Ticket_Cost'] = round(train['Fare']/train['Ticket_Count'], 4)
train.sort_values('Ticket_Count')
# Out:
#      Survived  Pclass  SibSp  Parch            Ticket Cabin Embarked   Age  \
# 0           0       3      1      0         A/5 21171   NaN        S  22.0
# 510         1       3      0      0            382651   NaN        Q  29.0
# 511         0       3      0      0  SOTON/OQ 3101316   NaN        S   NaN
# 512         1       1      0      0          PC 17473   E25        S  36.0
# 513         1       1      1      0          PC 17603   NaN        C  54.0
# ..        ...     ...    ...    ...               ...   ...      ...   ...
# 838         1       3      0      0              1601   NaN        S  32.0
# 846         0       3      4      2          CA. 2343   NaN        S   NaN
# 850         0       3      4      2            347082   NaN        S   4.0
# 826         0       3      0      0              1601   NaN        S   NaN
# 119         0       3      4      2            347082   NaN        S   2.0
#
# ...

# %%
train.drop('Ticket', axis=1, inplace=True)

# %% [markdown]
# ## <b>Cabin</b>

# %%
train['Cabin_NA'] = train.Cabin.isnull().astype(int)
train.drop('Cabin', axis=1, inplace=True)

# %% [markdown]
# ## <b>Embark</b>

# %%
train['Embarked'].mode()[0]
# Out:
# 'S'

# %%
train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)

# %%
train.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.countplot(x='Embarked', hue='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
train = pd.get_dummies(train, columns=['Embarked'], drop_first=True)

# %% [markdown]
# ### <b>Age</b>

# %% [markdown]
# 1. Outlier Treatment -> Use winsorization to replace last 99th percentile outlier. Use replacing technique instead of dropping the outlier here.
# 2. Imputing Missing data -> we will us KNNImputer to impute missing data

# %%
# Out:
#                 Survived    Pclass     SibSp     Parch       Age      Fare  \
# Age             0.077221  0.369226  0.308269  0.240955  1.000000  0.096067
# Pclass          0.338481  1.000000  0.067096  0.002457  0.369226  0.549500
# SibSp           0.010680  0.067096  1.000000  0.468342  0.308269  0.165933
# PaTitle_Miss    0.327093  0.000576  0.087542  0.132406  0.276792  0.118271
# Ticket_Count    0.038247  0.002633  0.651345  0.592265  0.253507  0.345541
# Cabin_NA        0.316912  0.725541  0.026883  0.052456  0.249732  0.482075
# Parch           0.106532  0.002457  0.468342  1.000000  0.240955  0.235347
# Ticket_Cost     0.254824  0.655559  0.000796  0.078216  0.227631  0.839037
# PaTitle_Mr      0.549199  0.142698  0.288648  0.357406  0.206341  0.183766
# PaTitle_Mrs     0.339040  0.149209  0.093442  0.206401  0.180278  0.105203
# PaTitle_Others  0.022030  0.206333  0.036928  0.071282  0.169880  0.024585
# ...

# %%
# Histogram to understand the distribution

plt.figure(figsize = (15, 5))
plt.title("Histogram to understand the distribution", fontweight='bold')
plt.xlabel('Age distribution')
plt.ylabel('Count')
plt.hist(train.Age, bins=20);
plt.show()

# Boxplot to understand distribution and check if there are outliers
plt.figure(figsize = (15,5))
plt.title("Boxplot to understand the distribution for each target variable", fontweight='bold')
plt.xlabel('Survived / Not-Survived')
plt.ylabel('Age')
sns.boxplot(y='Age', x='Survived', data=train)
plt.show()

# %%
train.Age.skew()
# Out:
# 0.38910778230082704

# %%
# Outliers (99th Quartile) - two methods
train[~train.Age.isnull()].Age.apply(lambda x: float(x)).quantile(0.99)

train[train.Age >= np.percentile(train[~train.Age.isnull()].Age, 99)]
# Out:
#      Survived  Pclass  SibSp  Parch   Age     Fare  PaTitle_Miss  PaTitle_Mr  \
# 33          0       2      0      0  66.0  10.5000             0           1
# 96          0       1      0      0  71.0  34.6542             0           1
# 116         0       3      0      0  70.5   7.7500             0           1
# 493         0       1      0      0  71.0  49.5042             0           1
# 630         1       1      0      0  80.0  30.0000             0           1
# 672         0       2      0      0  70.0  10.5000             0           1
# 745         0       1      1      1  70.0  71.0000             0           0
# 851         0       3      0      0  74.0   7.7750             0           1
#
#      PaTitle_Mrs  PaTitle_Others  Sex  Ticket_Count  Ticket_Cost  Cabin_NA  \
# 33             0               0    1             1      10.5000         1
# 96             0               0    1             1      34.6542         0
# ...

# %%
# capturing the ceiling value of outlier in a variable
ceiling = math.ceil(np.percentile(train[~train.Age.isnull()].Age, 99))

# Replacing value of Outlier Age with ceiling
train.loc[train.Age >= ceiling, 'Age'] = ceiling

# %%
# QA if the output looks as expected
train[~(train.Age.isnull())].sort_values('Age', ascending=False).head()
# Out:
#      Survived  Pclass  SibSp  Parch   Age     Fare  PaTitle_Miss  PaTitle_Mr  \
# 493         0       1      0      0  66.0  49.5042             0           1
# 851         0       3      0      0  66.0   7.7750             0           1
# 630         1       1      0      0  66.0  30.0000             0           1
# 96          0       1      0      0  66.0  34.6542             0           1
# 672         0       2      0      0  66.0  10.5000             0           1
#
#      PaTitle_Mrs  PaTitle_Others  Sex  Ticket_Count  Ticket_Cost  Cabin_NA  \
# 493            0               0    1             1      49.5042         1
# 851            0               0    1             1       7.7750         1
# 630            0               0    1             1      30.0000         0
# 96             0               0    1             1      34.6542         0
# 672            0               0    1             1      10.5000         1
#
#      Embarked_Q  Embarked_S
# ...

# %%
train.Age.skew()
# Out:
# 0.3123094826696491

# %%
# QA the updated data to ensure the output is as expected
plt.figure(figsize = (15,5))
plt.title("Boxplot to understand the distribution for each target variable", fontweight='bold')
plt.xlabel('Survived / Not-Survived')
plt.ylabel('Age')
sns.boxplot(y='Age', x='Survived', data=train)
plt.show()

# As we can see, outliers have been taken care of

# %%
abs(train.corr()).sort_values('Age', ascending=False)
# Out:
#                 Survived    Pclass     SibSp     Parch       Age      Fare  \
# Age             0.077351  0.370684  0.310010  0.242039  1.000000  0.097753
# Pclass          0.338481  1.000000  0.067096  0.002457  0.370684  0.549500
# SibSp           0.010680  0.067096  1.000000  0.468342  0.310010  0.165933
# PaTitle_Miss    0.327093  0.000576  0.087542  0.132406  0.277956  0.118271
# Ticket_Count    0.038247  0.002633  0.651345  0.592265  0.254207  0.345541
# Cabin_NA        0.316912  0.725541  0.026883  0.052456  0.250215  0.482075
# Parch           0.106532  0.002457  0.468342  1.000000  0.242039  0.235347
# Ticket_Cost     0.254824  0.655559  0.000796  0.078216  0.229083  0.839037
# PaTitle_Mr      0.549199  0.142698  0.288648  0.357406  0.205766  0.183766
# PaTitle_Mrs     0.339040  0.149209  0.093442  0.206401  0.184306  0.105203
# PaTitle_Others  0.022030  0.206333  0.036928  0.071282  0.170707  0.024585
# ...

# %%
abs(train.corr()).sort_values('Age', ascending=False).index
# Out:
# Index(['Age', 'Pclass', 'SibSp', 'PaTitle_Miss', 'Ticket_Count', 'Cabin_NA',
#        'Parch', 'Ticket_Cost', 'PaTitle_Mr', 'PaTitle_Mrs', 'PaTitle_Others',
#        'Fare', 'Sex', 'Survived', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
# Imputing missing data using KNNImputer

X = train.copy()

# Selecting columns that will help to determine the age. We will use Pclass, SubSp, Parch, Fare and Sex_male to create KNN model to impute age
X = X[['Pclass', 'SibSp', 'PaTitle_Miss', 'Ticket_Count', 'Cabin_NA',
       'Parch', 'Ticket_Cost', 'PaTitle_Mr', 'PaTitle_Mrs', 'PaTitle_Others',
       'Fare', 'Sex', 'Age']]

# %%
from sklearn.impute import KNNImputer
impute_knn = KNNImputer(n_neighbors=2)
X_impute = impute_knn.fit_transform(X)

X_impute = pd.DataFrame(X_impute, columns=X.columns)
X_impute.Age = X_impute.Age.round(2)

# Update the working DF with imputed Age
train['Age'] = X_impute['Age']

# %% [markdown]
# There is another imputer that uses Linear Regression to impute values:
#
# ```
# from sklearn.impute import IterativeImputer
# impute_it = IterativeImputer()
# y = impute_it.fit_transform(X)
# ```

# %%
train[(train.PaTitle_Miss == 0) & (train.PaTitle_Mr == 0) & (train.PaTitle_Mrs == 0) & (train.PaTitle_Others == 0) ].sort_values('Age')
# Out:
#      Survived  Pclass  SibSp  Parch    Age      Fare  PaTitle_Miss  \
# 803         1       3      0      1   0.42    8.5167             0
# 755         1       2      1      1   0.67   14.5000             0
# 831         1       2      1      1   0.83   18.7500             0
# 78          1       2      0      2   0.83   29.0000             0
# 305         1       1      1      2   0.92  151.5500             0
# 827         1       2      0      2   1.00   37.0042             0
# 788         1       3      1      2   1.00   20.5750             0
# 386         0       3      4      2   1.00   46.9000             0
# 164         0       3      4      1   1.00   39.6875             0
# 183         1       2      2      1   1.00   39.0000             0
# 7           0       3      3      1   2.00   21.0750             0
# 824         0       3      4      1   2.00   39.6875             0
# 340         1       2      1      1   2.00   26.0000             0
# ...

# %%
train
# Out:
#      Survived  Pclass  SibSp  Parch   Age     Fare  PaTitle_Miss  PaTitle_Mr  \
# 0           0       3      1      0  22.0   7.2500             0           1
# 1           1       1      1      0  38.0  71.2833             0           0
# 2           1       3      0      0  26.0   7.9250             1           0
# 3           1       1      1      0  35.0  53.1000             0           0
# 4           0       3      0      0  35.0   8.0500             0           1
# ..        ...     ...    ...    ...   ...      ...           ...         ...
# 886         0       2      0      0  27.0  13.0000             0           0
# 887         1       1      0      0  19.0  30.0000             1           0
# 888         0       3      1      2  26.0  23.4500             1           0
# 889         1       1      0      0  26.0  30.0000             0           1
# 890         0       3      0      0  32.0   7.7500             0           1
#
# ...

# %%
abs(train.corr()).sort_values('Fare', ascending=False)
# Out:
#                 Survived    Pclass     SibSp     Parch       Age      Fare  \
# Fare            0.257307  0.549500  0.165933  0.235347  0.088317  1.000000
# Ticket_Cost     0.254824  0.655559  0.000796  0.078216  0.210639  0.839037
# Pclass          0.338481  1.000000  0.067096  0.002457  0.354714  0.549500
# Cabin_NA        0.316912  0.725541  0.026883  0.052456  0.236118  0.482075
# Ticket_Count    0.038247  0.002633  0.651345  0.592265  0.240309  0.345541
# Survived        1.000000  0.338481  0.010680  0.106532  0.097632  0.257307
# Parch           0.106532  0.002457  0.468342  1.000000  0.245824  0.235347
# PaTitle_Mr      0.549199  0.142698  0.288648  0.357406  0.238641  0.183766
# Sex             0.543351  0.131900  0.135595  0.253454  0.134221  0.182333
# SibSp           0.010680  0.067096  1.000000  0.468342  0.287930  0.165933
# Embarked_S      0.149683  0.074053  0.058309  0.059091  0.024696  0.162184
# ...

# %%
abs(train.corr()).sort_values('Ticket_Cost', ascending=False)
# Out:
#                 Survived    Pclass     SibSp     Parch       Age      Fare  \
# Ticket_Cost     0.254824  0.655559  0.000796  0.078216  0.210639  0.839037
# Fare            0.257307  0.549500  0.165933  0.235347  0.088317  1.000000
# Pclass          0.338481  1.000000  0.067096  0.002457  0.354714  0.549500
# Cabin_NA        0.316912  0.725541  0.026883  0.052456  0.236118  0.482075
# Survived        1.000000  0.338481  0.010680  0.106532  0.097632  0.257307
# Age             0.097632  0.354714  0.287930  0.245824  1.000000  0.088317
# Embarked_S      0.149683  0.074053  0.058309  0.059091  0.024696  0.162184
# Sex             0.543351  0.131900  0.135595  0.253454  0.134221  0.182333
# Embarked_Q      0.003650  0.221009  0.019443  0.094445  0.000698  0.117216
# PaTitle_Mr      0.549199  0.142698  0.288648  0.357406  0.238641  0.183766
# PaTitle_Mrs     0.339040  0.149209  0.093442  0.206401  0.157570  0.105203
# ...

# %%
plt.hist(train.Fare);
train.Fare.skew()
# Out:
# 4.787316519674893

# %%
plt.hist(train.Ticket_Cost)
train.Ticket_Cost.skew()
# Out:
# 4.380561523143281

# %%
np.log(train.Ticket_Cost +1 ).sort_values().skew()
# Out:
# 0.3302208829499277

# %%
np.log(train.Fare +1 ).sort_values().skew()
# Out:
# 0.3949280095189299

# %%
plt.hist(np.log(train.Ticket_Cost +1))
# Out:
# (array([ 15.,   0.,   4., 155., 444.,  50., 150.,  56.,  10.,   7.]),
#  array([0.        , 0.54061811, 1.08123623, 1.62185434, 2.16247246,
#         2.70309057, 3.24370869, 3.7843268 , 4.32494492, 4.86556303,
#         5.40618115]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log(train.Fare +1))
# Out:
# (array([ 15.,   0.,   2., 350., 167., 182.,  85.,  59.,  28.,   3.]),
#  array([0.        , 0.62409174, 1.24818347, 1.87227521, 2.49636694,
#         3.12045868, 3.74455041, 4.36864215, 4.99273388, 5.61682562,
#         6.24091735]),
#  <BarContainer object of 10 artists>)

# %%
#temp = train.copy()
train['log_fare'] = np.log(train.Fare +1)
train['log_Ticket_Cost'] = np.log(train.Ticket_Cost +1)
train
# Out:
#      Survived  Pclass  SibSp  Parch   Age     Fare  PaTitle_Miss  PaTitle_Mr  \
# 0           0       3      1      0  22.0   7.2500             0           1
# 1           1       1      1      0  38.0  71.2833             0           0
# 2           1       3      0      0  26.0   7.9250             1           0
# 3           1       1      1      0  35.0  53.1000             0           0
# 4           0       3      0      0  35.0   8.0500             0           1
# ..        ...     ...    ...    ...   ...      ...           ...         ...
# 886         0       2      0      0  27.0  13.0000             0           0
# 887         1       1      0      0  19.0  30.0000             1           0
# 888         0       3      1      2  26.0  23.4500             1           0
# 889         1       1      0      0  26.0  30.0000             0           1
# 890         0       3      0      0  32.0   7.7500             0           1
#
# ...

# %%
train[['Age', 'Fare', 'Ticket_Cost', 'log_fare', 'log_Ticket_Cost']].skew()
# Out:
# Age                0.379887
# Fare               4.787317
# Ticket_Cost        4.380562
# log_fare           0.394928
# log_Ticket_Cost    0.330221
# dtype: float64

# %% [markdown]
# # <b>Classification</b>

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train[train.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
temp = train.sort_values('Age', ascending=False)

# %%
plt.plot(temp['Age'])

# %%
# Check if Age is normally distributed?
sns.boxplot(train['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
stats, p = shapiro(train[~train.Age.isnull()]['Age'])

print('Stats = %.3f , p = %.3f ' % (stats,  p))

#Shapiro-Wilk Test assumes that distribution is not normal
# Out:
# Stats = 0.981 , p = 0.000

# %%
sns.displot(train['Age'])

# %%
measurements = np.random.normal(size=150)

# %%
sns.boxplot(measurements)
# Out:
# <AxesSubplot:>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train.drop('Cabin', axis=1, inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train = pd.get_dummies(train, columns=['Sex', 'Embarked'], drop_first=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
train.Ticket.nunique()
# Out:
# 681

# %%
train[train.Ticket == '110465']
# Out:
#      PassengerId  Survived  Pclass                            Name   Age  \
# 110          111         0       1  Porter, Mr. Walter Chamberlain  47.0
# 475          476         0       1     Clifford, Mr. George Quincy   NaN
#
#      SibSp  Parch  Ticket  Fare  Sex_male  Embarked_Q  Embarked_S
# 110      0      0  110465  52.0         1           0           1
# 475      0      0  110465  52.0         1           0           1

# %%
temp = train[train.duplicated(subset=['Ticket'], keep=False)].sort_values('Ticket').reset_index()

# %%
temp.head(50)
# Out:
#     index  PassengerId  Survived  Pclass  \
# 0     257          258         1       1
# 1     759          760         1       1
# 2     504          505         1       1
# 3     262          263         0       1
# 4     558          559         1       1
# 5     585          586         1       1
# 6     110          111         0       1
# 7     475          476         0       1
# 8     523          524         1       1
# 9     329          330         1       1
# 10    166          167         1       1
# 11    356          357         1       1
# 12    829          830         1       1
# 13     61           62         1       1
# 14    390          391         1       1
# 15    802          803         1       1
# 16    435          436         1       1
# 17    763          764         1       1
# 18    151          152         1       1
# 19    336          337         0       1
# 20    498          499         0       1
# 21    708          709         1       1
# ...
